# %% [markdown]
# ## Template for Model Calibration

# %%
import pandas as pd
import numpy as np
from geoEpic.io import CropCom, ieParm
from geoEpic.core import Workspace

import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ### load parameter files and set sensitive parameters

# %%
cropcom = CropCom.load('./parms/defaults')

cropcom.set_sensitive(['./parms/sensitivity/cropcom_CY.csv', 
                       './parms/sensitivity/cropcom_LAI.csv'], [1, 2])

# save default cropcom file in the model dir.
cropcom.save('./model')

# %% [markdown]
# ##### Verify sensitive parameters

# %%
cropcom.prms
# Out:
#     ID   Parm                                   Parm.Description  Select  \
# 0    1     WA                Biomass-Energy Ratio (CO2 = 330ppm)       1
# 1    2     HI                                      Harvest Index       1
# 4    5   DMLA                  Maximum potential leaf area index       1
# 5    6   DLAI  Fraction of growing season when leaf area decl...       1
# 6    7  DLAP1  First point on optimal leaf area development c...       1
# 7    8  DLAP2  Second point on optimal leaf area development ...       1
# 8    9   RLAD             Leaf area index decline rate parameter       1
# 9   10   RBMD        Biomass-energy ratio decline rate parameter       1
# 11  12    GSI                       Maximum Stomatal Conductance       1
# 12  13    CAF                           Critical Aeration Factor       1
# 14  15    HMX                                Maximum crop height       1
# 20  21   WSYF                       Lower limit of harvest index       1
# 41  42   WAVP         Parm relating vapor pressure deficit to WA       1
# 47  48  PPLP1          Plant Population Crops & Grass 1st Point.       1
# 48  49  PPLP2          Plant Population Crops & Grass 2nd Point.       1
#
#        Min     Max   Category           Range
# 0   20.000  50.000      1,2,4    (20.0, 50.0)
# 1    0.300   1.000          4      (0.3, 1.0)
# 4    5.000   9.000          2      (5.0, 9.0)
# 5    0.600   1.000          2      (0.6, 1.0)
# 6   15.010  15.060          2  (15.01, 15.06)
# 7   50.930  50.970          2  (50.93, 50.97)
# 8    0.500   2.000          2      (0.5, 2.0)
# 9    0.500   1.500      1,2,4      (0.5, 1.5)
# 11   0.005   0.015  1,2,3,4,5  (0.005, 0.015)
# 12   0.800   0.900  1,2,3,4,5      (0.8, 0.9)
# 14   0.500   2.000      1,2,4      (0.5, 2.0)
# 20   0.210   0.450          4    (0.21, 0.45)
# 41   6.000   8.000      1,2,4      (6.0, 8.0)
# 47  30.400  30.450          2   (30.4, 30.45)
# 48  40.850  46.990          2  (40.85, 46.99)

# %%
ieparm = ieParm.load('./parms/defaults')
ieparm.set_sensitive(['./parms/sensitivity/parm_CY.csv', './parms/sensitivity/parm_LAI.csv'])
ieparm.save('./model')

# %%
ieparm.prms
# Out:
#       ID    Parm                                   Parm.Description  Select  \
# 60    61   PARM1                                        Crop canopy       1
# 70    71  PARM11             Moisture required for seed germination       1
# 87    88  PARM28                    Acceptable plant N stress level       1
# 109  110  PARM50                 Technology annual rate coefficient       1
# 113  114  PARM54  Exponential coefficient in potential water use...       1
# 114  115  PARM55         Coefficient used in allocating root growth       1
# 115  116  PARM56  Exponential coefficient in root growth distrib...       1
# 118  119  PARM59                  Soil water value to delay tillage       1
# 121  122  PARM62  Exponential coefficient regulates upward N mov...       1
# 122  123  PARM63  Upper limit of N concentration in percolating ...       1
# 125  126  PARM66     Converts standing dead residue to flat residue       1
# 127  128  PARM68                             N fixation upper limit       1
# 129  130  PARM70  Power of change in day length component of LAI...       1
#
#           Min       Max   Category  Unit             Range
# 60     1.0000      2.00  1,2,3,4,5   NaN        (1.0, 2.0)
# 70   -30.0000    -10.00      1,2,4   NaN    (-30.0, -10.0)
# 87     0.0000      1.00        1,4   NaN        (0.0, 1.0)
# 109    0.0000      0.01        4,5   NaN       (0.0, 0.01)
# 113    2.5000      7.50    1,2,4,5   NaN        (2.5, 7.5)
# 114    0.0000      1.00      1,2,4   NaN        (0.0, 1.0)
# 115    5.0000     10.00      1,2,3   NaN       (5.0, 10.0)
# 118    0.9700      1.00    1,2,4,5   NaN       (0.97, 1.0)
# 121    0.2000      2.00      1,2,4   NaN        (0.2, 2.0)
# 122  100.0000  10000.00    1,2,4,5   NaN  (100.0, 10000.0)
# 125    0.0001      0.05      1,2,4   NaN    (0.0001, 0.05)
# 127    1.0000     30.00      1,2,4   NaN       (1.0, 30.0)
# 129    1.0000     10.00    1,2,4,5   NaN       (1.0, 10.0)

# %% [markdown]
# ### Define a fitness function
#
# - fitness function is called after each workspace run, to get the objective of optimization

# %%
exp = Workspace('./config.yml')


@exp.logger
def lai_error(site):
    print(site.outputs['ACY'])
    return {'error': site.site_id}

# %% [markdown]
# ### Make pygmo problem

# %%
import pygmo as pg

problem = MakeProblem(fitness, cropcom, ieparm)

# %% [markdown]
# ### Run Calibration
# - Choose necessary settings and optimization algorithm
# - Follow this link for [pygmo docs](https://esa.github.io/pygmo2/overview.html)

# %%
algo = pg.algorithm(pg.pso(gen = 4))
algo.set_verbosity(1) 
pop = pg.population(pg.problem(problem), 30)
pop = algo.evolve(pop)
